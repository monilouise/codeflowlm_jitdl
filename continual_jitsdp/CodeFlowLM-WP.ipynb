# %% [markdown]
# # CodeFlowLM - Within-project Training

# %% [markdown]
# ## Code preparation

# %%
# !git clone https://github.com/monilouise/codeflowlm_jitdl.git

# %%
# !git clone https://github.com/monilouise/PEFT4CC.git

# %%
# !rm -r codeflowlm/

# %%
# !git clone https://github.com/monilouise/codeflowlm.git
# Out:
# Cloning into 'codeflowlm'...
# remote: Enumerating objects: 404, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 404 (delta 92), reused 165 (delta 78), pack-reused 222 (from 1)
# Receiving objects: 100% (404/404), 74.78 KiB | 5.34 MiB/s, done.
# Resolving deltas: 100% (202/202), done.

# %%
import sys
sys.path.append('codeflowlm')

# %%
path = 'codeflowlm_jitdl/data'
full_features_train_file = f"{path}/ord_cross_features_train.pkl"
full_features_valid_file = f"{path}/ord_cross_features_valid.pkl"
full_features_test_file = f"{path}/ord_cross_features_test.pkl"
full_changes_train_file = f"{path}/ord_cross_changes_train_lst.pkl"
full_changed_valid_file = f"{path}/ord_cross_changes_valid_lst.pkl"
full_changes_test_file = f"{path}/ord_cross_changes_test_lst.pkl"
commit_guru_path = f"{path}/commit_guru/"
model_root = "." #path where the models will be saved
batch_classifier_dir = '.' #e.g: PEFT4CC

# %% [markdown]
# ## Libraries installation

# %%
# !pip install river

# %%
# !pip install transformers==5.9.0

# %%
# !pip install huggingface_hub==1.16.4

# %%
# !pip install torchao==0.17.0

# %%
import codeflowlm.train

# %%
# Source - https://stackoverflow.com/a/66631469
# Posted by Phạm Ngọc Quý, modified by community. See post 'Timeline' for change history
# Retrieved 2026-05-25, License - CC BY-SA 4.0

import os
os.environ['DISABLE_SAFETENSORS_CONVERSION'] = 'True'
print(os.getenv('DISABLE_SAFETENSORS_CONVERSION'))

# %% [markdown]
# ## CodeT5+

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='ant-ivy', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-bcel', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-beanutils', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-codec', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-collections', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-compress', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-configuration', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-digester', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-jcs', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-lang', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-math', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-net', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-scxml', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-validator', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-vfs', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='giraph', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='gora', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='openenlp', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='parquet-mr', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True,
                                            batch_size=16, do_eval_with_all_negative=False)

# %%
# !rm -r .codet5p-770m/ *.csv

# %% [markdown]
# ## UniXCoder (Preffix Fine-tuning)

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='ant-ivy', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-bcel', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-beanutils', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-codec', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-collections', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-compress', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-configuration', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-digester', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-jcs', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-lang', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-math', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-net', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-scxml', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-validator', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-vfs', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='giraph', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='gora', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='opennlp', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='parquet-mr', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="pret",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %% [markdown]
# ## UniXCoder (LoRA)

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='ant-ivy', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-bcel', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-beanutils', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-codec', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-collections', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-compress', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-configuration', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-digester', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-jcs', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-lang', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-math', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-net', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-scxml', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-validator', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='commons-vfs', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='giraph', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='gora', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='opennlp', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv

# %%
codeflowlm.train.train_project_with_lat_ver(batch_classifier_dir, path, model_root, commit_guru_path,
                                            full_features_train_file, full_features_valid_file,
                                            full_features_test_file, full_changes_train_file,
                                            full_changed_valid_file, full_changes_test_file,
                                            project='parquet-mr', early_stop_metric='gmean',
                                            adjust_th=False, skewed_oversample=True, peft_alg="lora",
                                            batch_size=16, do_eval_with_all_negative=False,
                                            pretrained_model='unixcoder')

# %%
# !rm -r .unixcoder/ *.csv
